# %%
# !pip install lpips realesrgan numpy==1.26.4 scikit-image Pillow opencv_python kornia wandb git+https://github.com/openai/CLIP.git open_clip_torch torch==2.1.0 torchvision==0.16.0 pandas
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to C:\Users\ryanh\AppData\Local\Temp\pip-req-build-40x5htrv
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\ryanh\AppData\Local\Temp\pip-req-build-40x5htrv'

# %%
# !pip install basicsr

# %%
# !pip install matplotlib

# %%
from basicsr.archs.rrdbnet_arch import RRDBNet
