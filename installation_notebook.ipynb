# %%
# !pip install lpips numpy==1.26.4 scikit-image Pillow opencv_python kornia wandb git+https://github.com/openai/CLIP.git open_clip_torch torch==2.1.0 torchvision==0.16.0
# Out:
# ...
#   Cloning https://github.com/openai/CLIP.git to C:\Users\ryanh\AppData\Local\Temp\pip-req-build-9399fxug
#   Resolved https://github.com/openai/CLIP.git to commit d05afc436d78f1c48dc0dbf8e5980a9d471f35f6
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\ryanh\AppData\Local\Temp\pip-req-build-9399fxug'

# %%
# !pip install basicsr
# Out:
# ...
#   Using cached basicsr-1.4.2-py3-none-any.whl
# ...
#   Using cached addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# ...
#   Using cached future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached lmdb-2.2.0-cp311-cp311-win_amd64.whl.metadata (1.2 kB)
# ...
#   Using cached tb_nightly-2.21.0a20251023-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# ...
#   Using cached absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached grpcio-1.80.0-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# ...
#   Using cached markdown-3.10.2-py3-none-any.whl.metadata (5.1 kB)
# ...
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# ...
#   Using cached werkzeug-3.1.7-py3-none-any.whl.metadata (4.0 kB)
# ...
# Using cached addict-2.4.0-py3-none-any.whl (3.8 kB)
# Using cached future-1.0.0-py3-none-any.whl (491 kB)
# Using cached lmdb-2.2.0-cp311-cp311-win_amd64.whl (109 kB)
# Using cached tb_nightly-2.21.0a20251023-py3-none-any.whl (5.5 MB)
# ...

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------------------- ------- 6.6/8.1 MB 30.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 29.6 MB/s  0:00:00
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 44.3 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/6 [pyparsing]
#    ---------------------------------------- 0/6 [pyparsing]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
#    ------------- -------------------------- 2/6 [fonttools]
# ...
